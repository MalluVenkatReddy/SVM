# %%
Q1. What is the relationship between polynomial functions and kernel functions in machine learning 
algorithms?

# %% [markdown]
# #### The function of kernel is to take data as input and transform it into the required form. Different SVM algorithms use different types of kernel functions. These functions can be different types. For example linear, nonlinear, polynomial, radial basis function (RBF), and sigmoid.

# %%
Q2. How can we implement an SVM with a polynomial kernel in Python using Scikit-learn?

# %% [markdown]
# #### 2 independent feratures x1,x2 and dependent y are the features
# -- convert x1,x2 into x1**2, x2**2, x1*x2 features and all these 3 are independent features
#
# -- use train, test and split scikit function to model these 3 features
#
# -- use SVC wth kernel as 'linear' to fit the model from x_train and y_train and predict the output for x_test
#
# -- compute the score for y_test, y_pred

# %%
Q3. How does increasing the value of epsilon affect the number of support vectors in SVR?

# %% [markdown]
# #### If epsilon is zero, we can expect overfitting
# Parameter ε controls the width of the ε-insensitive zone, used to fit the training data. The value of ε can affect the number of support vectors used to construct the regression function. The bigger ε, the fewer support vectors are selected.

# %%
Q4. How does the choice of kernel function, C parameter, epsilon parameter, and gamma parameter 
affect the performance of Support Vector Regression (SVR)? Can you explain how each parameter works 
and provide examples of when you might want to increase or decrease its value?

# %%
from sklearn.model_selection import GridSearchCV
 
# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel':['linear'],
              'epsilon':[0.1,0.2,0.3]
              }

# %% [markdown]
# #### kernel: The purpose of using the kernel in research is to implement a model in a higher dimensional space (feature space) without having to define the mapping function from the input space to the feature space

# %% [markdown]
# #### C is a regularization parameter that controls the trade off between the achieving a low training error and a low testing error that is the ability to generalize your classifier to unseen data.

# %% [markdown]
# #### SVR has an additional tunable parameter ε (epsilon). The value of epsilon determines the width of the tube around the estimated function (hyperplane). Points that fall inside this tube are considered as correct predictions and are not penalized by the algorithm.

# %% [markdown]
# #### Gamma is a hyperparameter used with non-linear SVM. One of the most commonly used non-linear kernels is the radial basis function (RBF). Gamma parameter of RBF controls the distance of the influence of a single training point.

# %%
Q5. Assignment:
 Import the necessary libraries and load the dataset
 Split the dataset into training and testing sets
 Preprocess the data using any technique of your choice (e.g. scaling, normalization)
 Create an instance of the SVC classifier and train it on the training data
 Use the trained classifier to predict the labels of the testing data
 Evaluate the performance of the classifier using any metric of your choice (e.g. accuracy, 
precision, recall, F1-scoreK
 Tune the hyperparameters of the SVC classifier using GridSearchCV or RandomizedSearchCV to 
improve its performanc_
 Train the tuned classifier on the entire dataset
 Save the trained classifier to a file for future use.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_classification

# %%
x,y=make_classification(n_samples=1000,n_features=2,n_classes=2,n_redundant=0)

# %%
sns.scatterplot(x=pd.DataFrame(x)[0],y=pd.DataFrame(x)[1],hue=y)
# Out:
# <AxesSubplot:xlabel='0', ylabel='1'>

# %%
from sklearn.model_selection import train_test_split
x_train1,x_test1,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=10)

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()

# %%
x_train=scalar.fit_transform(x_train1)

# %%
x_test=scalar.fit_transform(x_test1)

# %%
x_train
# Out:
# array([[-0.82613302,  0.41371889],
#        [ 1.21039445, -1.30956206],
#        [-0.20913738, -0.82928169],
#        ...,
#        [-0.59393112, -1.02349672],
#        [ 0.39753191,  0.26152564],
#        [-0.36482271,  0.06348532]])

# %%
x_test
# Out:
# array([[-3.74373944e-01,  1.13937904e+00],
#        [ 9.54420195e-01, -6.87790563e-01],
#        [ 4.20643947e-01,  7.64832695e-01],
#        [-9.61335605e-01,  4.24125366e-01],
#        [-1.06268679e+00,  4.15352921e-01],
#        [-7.04502337e-01, -8.32971793e-02],
#        [ 1.21722875e+00, -1.27107256e+00],
#        [-1.47337456e+00, -4.91147909e-01],
#        [ 1.37535362e+00, -1.67646475e+00],
#        [-4.75797236e-01,  7.73880777e-01],
#        [ 7.26214318e-02,  8.22834677e-01],
#        [-1.56780418e+00,  7.51956595e-01],
#        [-1.98264366e-01,  1.28894888e+00],
#        [-5.42662683e-01,  8.12193699e-01],
#        [ 4.12212363e-02,  1.80296644e-01],
#        [-2.67520687e-01, -1.38901515e+00],
#        [-9.63430657e-01, -2.25539338e-01],
#        [ 6.94826553e-01,  4.11828464e-01],
#        [-1.96833096e-01,  1.27246599e+00],
#        [ 1.96881470e-01,  2.00190784e+00],
#        [ 1.50857278e-01, -4.74790109e-01],
#        [ 2.34059992e-01, -1.30497179e+00],
# ...

# %%
from sklearn.svm import SVC

# %%
svc=SVC()

# %%
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
y_pred=svc.predict(x_test)
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.87       115
#            1       0.91      0.87      0.89       135
#
#     accuracy                           0.88       250
#    macro avg       0.88      0.88      0.88       250
# weighted avg       0.88      0.88      0.88       250
#
# [[103  12]
#  [ 18 117]]
# 0.88

# %%
from sklearn.model_selection import GridSearchCV
 
# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel':['linear']
              }

# %%
grid=GridSearchCV(SVC(),param_grid=param_grid,refit=True,cv=5,verbose=3)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.793 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.853 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.860 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.853 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.833 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.793 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.853 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.860 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.853 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.833 total time=   0.0s
# [CV 1/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.793 total time=   0.0s
# ...

# %%
grid.best_params_
# Out:
# {'C': 0.1, 'gamma': 1, 'kernel': 'linear'}

# %%
y_pred1=grid.predict(x_test)
## Prediction
print(classification_report(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(accuracy_score(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85       115
#            1       0.87      0.87      0.87       135
#
#     accuracy                           0.86       250
#    macro avg       0.86      0.86      0.86       250
# weighted avg       0.86      0.86      0.86       250
#
# [[ 98  17]
#  [ 17 118]]
# 0.864

# %%
svc1=SVC(C= 0.1, gamma= 1, kernel= 'linear')

# %%
svc1.fit(x_train,y_train)
# Out:
# SVC(C=0.1, gamma=1, kernel='linear')

# %%
y_pred2=svc1.predict(x_test)
## Prediction
print(classification_report(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(accuracy_score(y_test,y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85       115
#            1       0.87      0.87      0.87       135
#
#     accuracy                           0.86       250
#    macro avg       0.86      0.86      0.86       250
# weighted avg       0.86      0.86      0.86       250
#
# [[ 98  17]
#  [ 17 118]]
# 0.864
